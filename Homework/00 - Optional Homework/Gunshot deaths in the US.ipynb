# %% [markdown]
# # **Gunshot deaths in the US**

# %% [markdown]
# ## **Load data**

# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Without pandas

# %%
GUNSHOT_DATA_PATH = './data/interactive_data.csv'

gunshots_data = []
header = []
with open(GUNSHOT_DATA_PATH, 'r') as gunshots_file:
    csvreader = csv.reader(gunshots_file)
    header = next(csvreader)
    for line in csvreader:
        gunshots_data.append(line)

print(header)
print(gunshots_data[0])
# Out:
# ['', 'Intent', 'Gender', 'Age', 'Race', 'Deaths', 'Population', 'Rate']
# ['1', 'None selected', 'None selected', 'None selected', 'None selected', '33599', '316299978', '10.6']

# %% [markdown]
# ### With pandas

# %%
GUNSHOT_DATA_PATH = './data/interactive_data.csv'

gunshots_data = pd.read_csv(GUNSHOT_DATA_PATH)
gunshots_data
# Out:
#      Unnamed: 0         Intent         Gender            Age  \
# 0             1  None selected  None selected  None selected
# 1             2  None selected  None selected  None selected
# 2             3  None selected  None selected  None selected
# 3             4  None selected  None selected  None selected
# 4             5  None selected  None selected  None selected
# ..          ...            ...            ...            ...
# 535         536        Unknown           Male              5
# 536         537        Unknown           Male              5
# 537         538        Unknown           Male              5
# 538         539        Unknown           Male              5
# 539         540        Unknown           Male              5
#
#                        Race  Deaths  Population  Rate
# 0             None selected   33599   316299978  10.6
# 1                     White   22079   197369634  11.2
# 2                     Black    7765    38896382  20.0
# 3                  Hispanic    3007    54049078   5.6
# 4    Asian/Pacific Islander     442    16315561   2.7
# ..                      ...     ...         ...   ...
# 535                   White       0           0   NaN
# 536                   Black       0           0   NaN
# 537                Hispanic       0           0   NaN
# 538  Asian/Pacific Islander       0           0   NaN
# 539                   Other       0           0   NaN
#
# [540 rows x 8 columns]

# %% [markdown]
# ## **Statistics**

# %% [markdown]
# ### **Suicide rates**

# %%
gunshots_data_clean_intent = gunshots_data.query("Intent != 'None selected'") # clean data for intent

nb_deaths = gunshots_data_clean_intent['Deaths'].sum()
suicides_data = gunshots_data_clean_intent.query("Intent == 'Suicide'")
nb_suicides = suicides_data['Deaths'].sum()

print(nb_deaths)
print(nb_suicides)
suicides_data
# Out:
# 268789
# 168464
#      Unnamed: 0   Intent         Gender            Age  \
# 108         109  Suicide  None selected  None selected
# 109         110  Suicide  None selected  None selected
# 110         111  Suicide  None selected  None selected
# 111         112  Suicide  None selected  None selected
# 112         113  Suicide  None selected  None selected
# ..          ...      ...            ...            ...
# 211         212  Suicide           Male              5
# 212         213  Suicide           Male              5
# 213         214  Suicide           Male              5
# 214         215  Suicide           Male              5
# 215         216  Suicide           Male              5
#
#                        Race  Deaths  Population  Rate
# 108           None selected   21058   316299978   6.7
# 109                   White   18457   197369634   9.4
# 110                   Black    1111    38896382   2.9
# 111                Hispanic    1057    54049078   2.0
# 112  Asian/Pacific Islander     248    16315561   1.5
# ..                      ...     ...         ...   ...
# 211                   White       1           0   inf
# 212                   Black       0           0   NaN
# 213                Hispanic       0           0   NaN
# 214  Asian/Pacific Islander       0           0   NaN
# 215                   Other       0           0   NaN
#
# [108 rows x 8 columns]

# %%
print("%.1f%% of gunshot deaths in the US are suicides" % (100*nb_suicides/nb_deaths))
# Out:
# 62.7% of gunshot deaths in the US are suicides

# %% [markdown]
# ### **Male proportion of suicides**

# %%
suicides_data_clean_gender = suicides_data.query("Gender != 'None selected'") # clean data for gender
nb_suicides = suicides_data_clean_gender['Deaths'].sum()

male_suicides = suicides_data_clean_gender.query("Gender == 'Male'")
nb_male_suicides = male_suicides['Deaths'].sum()

print(nb_male_suicides)
print(nb_suicides)
male_suicides
# Out:
# 72646
# 84233
#      Unnamed: 0   Intent Gender            Age                    Race  \
# 180         181  Suicide   Male  None selected           None selected
# 181         182  Suicide   Male  None selected                   White
# 182         183  Suicide   Male  None selected                   Black
# 183         184  Suicide   Male  None selected                Hispanic
# 184         185  Suicide   Male  None selected  Asian/Pacific Islander
# 185         186  Suicide   Male  None selected                   Other
# 186         187  Suicide   Male       Under 15           None selected
# 187         188  Suicide   Male       Under 15                   White
# 188         189  Suicide   Male       Under 15                   Black
# 189         190  Suicide   Male       Under 15                Hispanic
# 190         191  Suicide   Male       Under 15  Asian/Pacific Islander
# 191         192  Suicide   Male       Under 15                   Other
# 192         193  Suicide   Male        15 - 34           None selected
# 193         194  Suicide   Male        15 - 34                   White
# 194         195  Suicide   Male        15 - 34                   Black
# 195         196  Suicide   Male        15 - 34                Hispanic
# 196         197  Suicide   Male        15 - 34  Asian/Pacific Islander
# 197         198  Suicide   Male        15 - 34                   Other
# 198         199  Suicide   Male        35 - 64           None selected
# 199         200  Suicide   Male        35 - 64                   White
# 200         201  Suicide   Male        35 - 64                   Black
# 201         202  Suicide   Male        35 - 64                Hispanic
# 202         203  Suicide   Male        35 - 64  Asian/Pacific Islander
# 203         204  Suicide   Male        35 - 64                   Other
# 204         205  Suicide   Male            65+           None selected
# 205         206  Suicide   Male            65+                   White
# 206         207  Suicide   Male            65+                   Black
# 207         208  Suicide   Male            65+                Hispanic
# 208         209  Suicide   Male            65+  Asian/Pacific Islander
# 209         210  Suicide   Male            65+                   Other
# 210         211  Suicide   Male              5           None selected
# 211         212  Suicide   Male              5                   White
# 212         213  Suicide   Male              5                   Black
# 213         214  Suicide   Male              5                Hispanic
# 214         215  Suicide   Male              5  Asian/Pacific Islander
# 215         216  Suicide   Male              5                   Other
#
#      Deaths  Population  Rate
# 180   18162   155631868  11.7
# 181   15852    97207346  16.3
# 182     989    18533996   5.3
# 183     941    27378155   3.4
# 184     215     7726442   2.8
# 185     164     4785929   3.4
# 186     114    31249189   0.4
# 187      98    16182922   0.6
# 188       6     4228176   0.1
# 189       9     7664425   0.1
# 190       2     1431715   0.1
# 191       0     1741952   0.0
# 192    4399    44017869  10.0
# 193    3339    24831032  13.4
# 194     466     5869943   7.9
# 195     424     9379683   4.5
# 196      92     2415040   3.8
# 197      78     1522171   5.1
# 198    8991    60810870  14.8
# 199    8005    40585343  19.7
# 200     411     6915685   5.9
# 201     405     8914219   4.5
# 202      99     3129535   3.2
# 203      71     1266087   5.6
# 204    4656    19553940  23.8
# 205    4409    15608050  28.2
# 206     106     1520192   7.0
# 207     104     1419828   7.3
# 208      22      750151   2.9
# 209      14      255719   5.5
# 210       2           0   inf
# 211       1           0   inf
# 212       0           0   NaN
# 213       0           0   NaN
# 214       0           0   NaN
# 215       0           0   NaN

# %%
print("%.1f%% of gunshot suicide victims are male" % (100*nb_male_suicides/nb_suicides))
# Out:
# 86.2% of gunshot suicide victims are male

# %% [markdown]
# ### **Homicide rates**

# %%
homicides_data = gunshots_data_clean_intent.query("Intent == 'Homicide'")
nb_homicides = homicides_data['Deaths'].sum()

homicides_data
# Out:
#      Unnamed: 0    Intent         Gender            Age  \
# 216         217  Homicide  None selected  None selected
# 217         218  Homicide  None selected  None selected
# 218         219  Homicide  None selected  None selected
# 219         220  Homicide  None selected  None selected
# 220         221  Homicide  None selected  None selected
# ..          ...       ...            ...            ...
# 319         320  Homicide           Male              5
# 320         321  Homicide           Male              5
# 321         322  Homicide           Male              5
# 322         323  Homicide           Male              5
# 323         324  Homicide           Male              5
#
#                        Race  Deaths  Population  Rate
# 216           None selected   11726   316299978   3.7
# 217                   White    3049   197369634   1.5
# 218                   Black    6503    38896382  16.7
# 219                Hispanic    1878    54049078   3.5
# 220  Asian/Pacific Islander     186    16315561   1.1
# ..                      ...     ...         ...   ...
# 319                   White       2           0   inf
# 320                   Black       0           0   NaN
# 321                Hispanic       0           0   NaN
# 322  Asian/Pacific Islander       0           0   NaN
# 323                   Other       0           0   NaN
#
# [108 rows x 8 columns]

# %%
print("%.1f%% of gunshot deaths in the US are homicides" % (100*nb_homicides/nb_deaths))
# Out:
# 34.9% of gunshot deaths in the US are homicides

# %% [markdown]
# ### **Young black men victims of homicides**

# %%
homicides_data_clean_agr = homicides_data.query("Gender == 'Male' & Age == '15 - 34' & Race != 'None selected'") # clean data for age, gender and race
nb_ym_homicides = homicides_data_clean_agr['Deaths'].sum()

black_data = homicides_data_clean_agr.query("Race == 'Black'")
nb_black = black_data['Deaths'].sum()

print(nb_black)
print(nb_ym_homicides)
black_data
# Out:
# 4312
# 6521
#      Unnamed: 0    Intent Gender      Age   Race  Deaths  Population  Rate
# 302         303  Homicide   Male  15 - 34  Black    4312     5869943  73.5

# %%
print("%.1f%% of the young men victims of homicide are black" % (100*nb_black/nb_ym_homicides))
# Out:
# 66.1% of the young men victims of homicide are black

# %% [markdown]
# ### **Women victim of homicide**

# %%
homicides_data_clean_gender = homicides_data.query("Gender != 'None selected'")
nb_homicides = homicides_data_clean_gender['Deaths'].sum()

women_data = homicides_data_clean_gender.query("Gender == 'Female'")
nb_women = women_data['Deaths'].sum()

print(nb_women)
print(nb_homicides)

women_data
# Out:
# 7167
# 46906
#      Unnamed: 0    Intent  Gender            Age                    Race  \
# 252         253  Homicide  Female  None selected           None selected
# 253         254  Homicide  Female  None selected                   White
# 254         255  Homicide  Female  None selected                   Black
# 255         256  Homicide  Female  None selected                Hispanic
# 256         257  Homicide  Female  None selected  Asian/Pacific Islander
# 257         258  Homicide  Female  None selected                   Other
# 258         259  Homicide  Female       Under 15           None selected
# 259         260  Homicide  Female       Under 15                   White
# 260         261  Homicide  Female       Under 15                   Black
# 261         262  Homicide  Female       Under 15                Hispanic
# 262         263  Homicide  Female       Under 15  Asian/Pacific Islander
# 263         264  Homicide  Female       Under 15                   Other
# 264         265  Homicide  Female        15 - 34           None selected
# 265         266  Homicide  Female        15 - 34                   White
# 266         267  Homicide  Female        15 - 34                   Black
# 267         268  Homicide  Female        15 - 34                Hispanic
# 268         269  Homicide  Female        15 - 34  Asian/Pacific Islander
# 269         270  Homicide  Female        15 - 34                   Other
# 270         271  Homicide  Female        35 - 64           None selected
# 271         272  Homicide  Female        35 - 64                   White
# 272         273  Homicide  Female        35 - 64                   Black
# 273         274  Homicide  Female        35 - 64                Hispanic
# 274         275  Homicide  Female        35 - 64  Asian/Pacific Islander
# 275         276  Homicide  Female        35 - 64                   Other
# 276         277  Homicide  Female            65+           None selected
# 277         278  Homicide  Female            65+                   White
# 278         279  Homicide  Female            65+                   Black
# 279         280  Homicide  Female            65+                Hispanic
# 280         281  Homicide  Female            65+  Asian/Pacific Islander
# 281         282  Homicide  Female            65+                   Other
# 282         283  Homicide  Female              5           None selected
# 283         284  Homicide  Female              5                   White
# 284         285  Homicide  Female              5                   Black
# 285         286  Homicide  Female              5                Hispanic
# 286         287  Homicide  Female              5  Asian/Pacific Islander
# 287         288  Homicide  Female              5                   Other
#
#      Deaths  Population  Rate
# 252    1791   160668110   1.1
# 253     860   100162288   0.9
# 254     633    20362385   3.1
# 255     232    26670924   0.9
# 256      47     8589119   0.5
# 257      20     4883395   0.4
# 258      85    29836679   0.3
# 259      38    15355910   0.2
# 260      27     4095428   0.7
# 261      19     7330024   0.3
# 262       1     1393440   0.1
# 263       1     1661877   0.1
# 264     815    42593280   1.9
# 265     267    23942099   1.1
# 266     389     6023846   6.5
# 267     131     8580577   1.5
# 268      16     2535358   0.6
# 269      13     1511400   0.9
# 270     733    63125058   1.2
# 271     426    41284839   1.0
# 272     199     7932606   2.5
# 273      76     8863203   0.9
# 274      26     3668172   0.7
# 275       6     1376239   0.4
# 276     158    25113094   0.6
# 277     129    19579439   0.7
# 278      18     2310506   0.8
# 279       6     1897119   0.3
# 280       4      992150   0.4
# 281       1      333879   0.3
# 282       0           0   NaN
# 283       0           0   NaN
# 284       0           0   NaN
# 285       0           0   NaN
# 286       0           0   NaN
# 287       0           0   NaN

# %%
print("%.1f%% of the homicide victims are women" % (100*nb_women/nb_homicides))
# Out:
# 15.3% of the homicide victims are women
